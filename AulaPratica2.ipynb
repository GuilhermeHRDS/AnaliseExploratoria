# %% [markdown]
# <a href="https://colab.research.google.com/github/GuilhermeHRDS/AnaliseExploratoria/blob/main/AulaPratica2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# The UserWarning "No artists with labels found to put in legend" indicates that `plt.legend()`
# was called without explicit labels or when the legend was already handled by seaborn's `hue` parameter.
# To fix this, remove the `plt.legend(loc="center")` line from your plotting cells (qWyOmR0vAhUU and M1WbSjZEBYGe).
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv("https://raw.githubusercontent.com/dayanebravo/AED/main/pes_2012.csv")
df1.head()
# Out:
#    V0101        UF      V0302  V8005   V0404            V4803 V4718 V4720  \
# 0   2012  Rondônia  Masculino     48  Branca  15 anos ou mais  3000  3000
# 1   2012  Rondônia   Feminino     48  Branca  15 anos ou mais  3000  3000
# 2   2012  Rondônia   Feminino     23  Branca  15 anos ou mais  1100  1100
# 3   2012  Rondônia   Feminino     21  Branca          14 anos  1100  1100
# 4   2012  Rondônia   Feminino     54  Branca  15 anos ou mais   NaN   460
#
#    V4729
# 0    232
# 1    232
# 2    232
# 3    232
# 4    232

# %%
df1["V4718"] = pd.to_numeric(df1["V4718"], errors="coerce")
df1["V4720"] = pd.to_numeric(df1["V4720"], errors="coerce")

# %%
df = df1.dropna()
df.head()
# Out:
#    V0101        UF      V0302  V8005   V0404            V4803    V4718  \
# 0   2012  Rondônia  Masculino     48  Branca  15 anos ou mais   3000.0
# 1   2012  Rondônia   Feminino     48  Branca  15 anos ou mais   3000.0
# 2   2012  Rondônia   Feminino     23  Branca  15 anos ou mais   1100.0
# 3   2012  Rondônia   Feminino     21  Branca          14 anos   1100.0
# 5   2012  Rondônia  Masculino     56   Preta  15 anos ou mais  10000.0
#
#      V4720  V4729
# 0   3000.0    232
# 1   3000.0    232
# 2   1100.0    232
# 3   1100.0    232
# 5  10000.0    232

# %%
#Bibliotecas par agrafico

import matplotlib.pyplot as plt #Biblioteca para graficos
import seaborn as sn

# %%
sn.set(style="whitegrid")

# %%
#Grafico de Barras Horizontal
ax = sn.countplot(y=df.V0302, hue=df.V0302)
plt.title("Sexo")
plt.ylabel("")
plt.xlabel("")

# Para mostrar a legenda corretamente quando usamos o hue
plt.legend(title='Sexo', loc='center right', bbox_to_anchor=(1.25, 0.5))

plt.show()

# %%
#Grafico de Barras Vertical
ax = sn.countplot(x=df.V0302, hue=df.V0302)
plt.title("Sexo")
plt.ylabel("")
plt.xlabel("")

# Ajustando a legenda para não sobrepor as barras
plt.legend(title='Sexo', loc='upper right')

plt.show()

# %%
sn.countplot(x=df.V0302, hue=df.V0404)
plt.title("Sexo")
plt.ylabel("")
plt.xlabel("")
plt.legend(loc="center")

plt.legend(bbox_to_anchor=(1.3, 0.8))

plt.show()

# %%
from matplotlib.patches import bbox_artist
# grafico de Sizes (Pizza)

sizes = df.V0404.value_counts()
h = df["V0404"].value_counts().index
plt.figure(figsize=(8,8))

plt.pie(sizes, labels=h, explode=(0,0,0.2,0.3,0.4), autopct='%1.2f%%',  startangle=90)
plt.legend(bbox_to_anchor=(1.3, 0.8))
plt.show()

# %%
sizes = df['V0404'].value_counts()

sizes.plot(kind='pie', fontsize=12, explode=(0,0,0.1,0.2,0.3), autopct='%1.2f%%', labeldistance=1, startangle=15)

plt.axis('equal')
plt.ylabel('')
plt.legend(bbox_to_anchor=(1.3, 0.8))
plt.show()

# %% [markdown]
# Grafico de Frenquencia Absoluta

# %%
sizes = df.V0404
plt.figure(figsize=(5,5))

sn.histplot(sizes, bins=5)

plt.ylabel('Frequência pessoas')
plt.xlabel('')
plt.show()

# %% [markdown]
# Grafico de Frequencia acumulativo

# %%
sizes = df.V0404
plt.figure(figsize=(5,5))

sn.histplot(sizes, bins=5 , cumulative=True)

plt.ylabel('Frequência pessoas')
plt.xlabel('')
plt.show()

# %%
sizes = df.V0404.sort_values(ascending=True)
plt.figure(figsize=(5,5))

sn.histplot(sizes, bins=5 , cumulative=True)

plt.ylabel('Frequência pessoas')
plt.xlabel('')
plt.show()

# %% [markdown]
# Grafico de Frequencia Relativa

# %%
sizes = np.divide(df.V0404.value_counts(), len(df.V0404))
plt.figure(figsize=(5,5))

plt.plot(sizes)

plt.ylabel('Frequência pessoas')
plt.xlabel('Caract. Físicas')
plt.show()
